# %%
import pandas as pd

# %%
df = pd.read_csv('ETH_1h.csv')
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.shape
# Out:
# (23674, 7)

# %%
df["Date"][0]
# Out:
# '2020-03-13 08-PM'

# %%
df.loc[0, "Date"]
# Out:
# '2020-03-13 08-PM'

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d %I-%p")

# %%
df["Date"]
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df["Date"][0].day_name()
# Out:
# 'Friday'

# %%
df.loc[0, "Date"].day_name()
# Out:
# 'Friday'

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p') 
df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# C:\Users\Ekaterine\AppData\Local\Temp\ipykernel_5448\298527242.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\base_parser.py:1176, in _make_date_converter.<locals>.converter(col, *date_cols)
#    1169     warnings.filterwarnings(
#    1170         "ignore",
#    1171         ".*parsing datetimes with mixed time zones "
#    1172         "will raise an error",
#    1173         category=FutureWarning,
#    1174     )
#    1175     result = tools.to_datetime(
# -> 1176         date_parser(
# ...

# %%
type(df["Date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df["Date"][0]
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"][0].day_name()
# Out:
# 'Friday'

# %%
df["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df["Weekday"] = df["Date"].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#         Weekday
# ...

# %%
df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"].max() - df["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df["Date"] >= '2020-01') & (df["Date"] <= '2020-02')
df[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close     Volume  \
# 1004 2020-02-01 00:00:00  ETHUSD  179.74  181.41  179.00  181.06  637332.52
# 1005 2020-01-31 23:00:00  ETHUSD  181.73  181.73  179.00  179.74  438575.26
# 1006 2020-01-31 22:00:00  ETHUSD  180.66  182.24  180.03  181.73  754254.39
# 1007 2020-01-31 21:00:00  ETHUSD  180.31  181.04  179.98  180.66  657922.36
# 1008 2020-01-31 20:00:00  ETHUSD  179.19  180.51  179.13  180.31  979846.20
# ...                  ...     ...     ...     ...     ...     ...        ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56  702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57  496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37  396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14  635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34  245119.91
#
#         Weekday
# 1004   Saturday
# 1005     Friday
# ...

# %%
filt = (df["Date"] >= pd.to_datetime('2020-01-13')) & (df["Date"] <= pd.to_datetime('2020-02-15'))
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 668  2020-02-15 00:00:00  ETHUSD  286.27  290.00  285.10  286.39  5146513.87
# 669  2020-02-14 23:00:00  ETHUSD  284.13  287.98  282.68  286.27  2265638.82
# 670  2020-02-14 22:00:00  ETHUSD  282.79  284.53  281.32  284.13  2552361.21
# 671  2020-02-14 21:00:00  ETHUSD  283.24  284.50  281.64  282.79  2068601.56
# 672  2020-02-14 20:00:00  ETHUSD  283.44  284.22  281.38  283.24  1715223.25
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1456 2020-01-13 04:00:00  ETHUSD  143.30  143.85  143.00  143.65   269860.60
# 1457 2020-01-13 03:00:00  ETHUSD  142.87  143.70  142.59  143.30   479871.44
# 1458 2020-01-13 02:00:00  ETHUSD  145.15  145.43  142.60  142.87   563666.35
# 1459 2020-01-13 01:00:00  ETHUSD  144.92  145.30  144.82  145.15   331330.66
# 1460 2020-01-13 00:00:00  ETHUSD  146.60  147.00  144.78  144.92   486778.84
#
#        Weekday
# 668   Saturday
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                       Weekday
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                      Weekday
# Date
# 2019-12-31 23:00:00  Tuesday
# 2019-12-31 22:00:00  Tuesday
# ...

# %%
df.loc['2019-01-01']['Open'].mean()
# Out:
# 133.53791666666666

# %%
df.loc['2019-01-01']['Open'].max()
# Out:
# 138.21

# %%
df.loc['2019-01-01']['Open'].max()
# Out:
# 138.21

# %%
df.loc['2019-01-01']['Open'].mean()
# Out:
# 133.53791666666666

# %%
df["Open"].resample('D').max()
# Out:
# Date
# 2017-07-01    279.98
# 2017-07-02    292.54
# 2017-07-03    285.00
# 2017-07-04    282.58
# 2017-07-05    271.00
#                ...
# 2020-03-09    207.79
# 2020-03-10    205.79
# 2020-03-11    202.48
# 2020-03-12    194.61
# 2020-03-13    134.03
# Freq: D, Name: Open, Length: 987, dtype: float64

# %%
df["Open"].resample('W').max()
# Out:
# Date
# 2017-07-02    292.54
# 2017-07-09    285.00
# 2017-07-16    238.81
# 2017-07-23    245.55
# 2017-07-30    229.96
#                ...
# 2020-02-16    286.39
# 2020-02-23    285.30
# 2020-03-01    276.91
# 2020-03-08    247.62
# 2020-03-15    207.79
# Freq: W-SUN, Name: Open, Length: 142, dtype: float64

# %%
df["Open"].resample('Y').max()
# Out:
# Date
# 2017-12-31     858.90
# 2018-12-31    1418.61
# 2019-12-31     355.31
# 2020-12-31     286.39
# Freq: A-DEC, Name: Open, dtype: float64

# %%
df["Open"].resample('Y').mean()
# Out:
# Date
# 2017-12-31    351.863442
# 2018-12-31    481.001922
# 2019-12-31    180.752257
# 2020-12-31    197.568662
# Freq: A-DEC, Name: Open, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
high = df["High"].resample('D').max()
high
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
high.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
high_1 = df["High"].resample('M').mean()

# %%
high_1
# Out:
# Date
# 2017-07-31     222.516126
# 2017-08-31     300.082661
# 2017-09-30     301.120875
# 2017-10-31     306.866976
# 2017-11-30     357.946500
# 2017-12-31     636.534435
# 2018-01-31    1096.335121
# 2018-02-28     880.735893
# 2018-03-31     634.618750
# 2018-04-30     519.375875
# 2018-05-31     680.985820
# 2018-06-30     522.716236
# 2018-07-31     463.801478
# 2018-08-31     324.968172
# 2018-09-30     228.635569
# 2018-10-31     208.394355
# 2018-11-30     169.430153
# 2018-12-31     108.331989
# 2019-01-31     127.757675
# 2019-02-28     125.442440
# 2019-03-31     135.835269
# 2019-04-30     165.852611
# 2019-05-31     219.682258
# 2019-06-30     275.520583
# 2019-07-31     250.382433
# 2019-08-31     200.667648
# 2019-09-30     186.109028
# 2019-10-31     179.176989
# 2019-11-30     173.834333
# 2019-12-31     137.882513
# 2020-01-31     155.884745
# 2020-02-29     239.790216
# 2020-03-31     211.107379
# Freq: M, Name: High, dtype: float64

# %%
high_1.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('W').max()
# Out:
#             Symbol    Open    High     Low   Close       Volume    Weekday
# Date
# 2017-07-02  ETHUSD  292.54  293.73  284.87  292.54   7081816.11     Sunday
# 2017-07-09  ETHUSD  285.00  285.00  282.31  282.58   6082287.50  Wednesday
# 2017-07-16  ETHUSD  238.81  240.33  238.00  238.47  23582117.48  Wednesday
# 2017-07-23  ETHUSD  245.55  249.40  234.97  245.55  31082353.62  Wednesday
# 2017-07-30  ETHUSD  229.96  229.99  229.60  229.96   9214814.73  Wednesday
# ...            ...     ...     ...     ...     ...          ...        ...
# 2020-02-16  ETHUSD  286.39  290.00  285.10  286.39  13323454.31  Wednesday
# 2020-02-23  ETHUSD  285.30  287.13  282.00  285.30  12085035.32  Wednesday
# 2020-03-01  ETHUSD  276.91  278.13  274.28  276.91  19074673.60  Wednesday
# 2020-03-08  ETHUSD  247.62  253.01  245.01  247.62   8804126.61  Wednesday
# 2020-03-15  ETHUSD  207.79  208.65  205.83  207.79  19731142.71  Wednesday
#
# [142 rows x 7 columns]

# %%
df.resample('W').agg({'Open':['mean', 'max', 'std'], 'High':'median', 'Low':'mean'})
# Out:
#                   Open                        High         Low
#                   mean     max        std   median        mean
# Date
# 2017-07-02  268.066486  292.54   9.016119  268.440  264.819730
# 2017-07-09  261.337024  285.00  14.557426  265.925  259.186190
# 2017-07-16  196.193214  238.81  22.399114  201.030  192.722321
# 2017-07-23  212.351429  245.55  21.653778  224.935  209.126310
# 2017-07-30  203.496190  229.96  12.812609  202.305  201.714048
# ...                ...     ...        ...      ...         ...
# 2020-02-16  255.021667  286.39  21.586294  267.000  252.679762
# 2020-02-23  265.220833  285.30   9.171439  264.590  262.948512
# 2020-03-01  236.720536  276.91  17.708450  231.540  234.208750
# 2020-03-08  229.923571  247.62   8.130261  230.550  228.373810
# 2020-03-15  176.937521  207.79  32.647326  197.490  172.936239
#
# [142 rows x 5 columns]

# %%
df['Open'].describe()
# Out:
# count    23674.000000
# mean       324.933372
# std        236.189068
# min         81.290000
# 25%        171.522500
# 50%        229.745000
# 75%        402.797500
# max       1418.610000
# Name: Open, dtype: float64
